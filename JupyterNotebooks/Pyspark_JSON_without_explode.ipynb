# %%
# All imports go here
import pyspark
from pyspark.sql.functions import col
from pyspark.sql.types import StructType, ArrayType  

# Function to flatten a nested schema
def flatten(df):
    connector = '-'  # Separator for flattened column names
    
    # Recursive function to flatten a schema
    def flattenSchema(schema, prefix=None):
        fields = []
        
        for field in schema.fields:
            # Check if the field name contains dot notation
            if '.' in field.name:
                name = prefix + '.' + '`' + field.name + '`' if prefix else '`' + field.name + '`'
            else:
                name = prefix + '.' + field.name if prefix else field.name
            dtype = field.dataType
            
            # If the field is an array, get its elementType
            if isinstance(dtype, ArrayType):
                dtype = dtype.elementType
                
            # If the field is a struct, recursively flatten its schema
            if isinstance(dtype, StructType):
                fields += flattenSchema(dtype, prefix=name)
            else:
                fields.append(name)
        return fields
    
    newDf = df
    
    # Flatten the schema and create flattened columns
    for col_name in flattenSchema(df.schema):
        newDf = newDf.withColumn(col_name.replace('`', '').replace('.', connector), col(col_name))
    
    # Drop original struct columns from the DataFrame
    for field in newDf.schema:
        if isinstance(field.dataType, StructType):
            newDf = newDf.drop(field.name)
            
    newDf.show()  # Show the flattened DataFrame
    return newDf

# Initialize Spark session
spark = pyspark.sql.SparkSession.builder.appName("Flatten_JSON").getOrCreate()

# Load JSON file into a DataFrame
df = spark.read.format("json").load("dbfs:/FileStore/shared_uploads/chaitu.wynbit@outlook.com/exampleEliteJSON-1.json", multiLine=True)

# Apply the flatten function to flatten the DataFrame
flattened_df = flatten(df)
# Out:
# +--------------------+------------+--------------------+--------------------+-------------------------+----------------+--------------+------+--------------------+-----------------------+----------------+------------+---------------+------+--------+---------------+--------------+--------------------+---------------+---------------------+--------------------+-------------------+---------------------------+------------------------+----------------+---------------------------------+----------------------------+---------------------------------------------+-----------------------------+------------------------------------------+----------------------------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------------------+---------------------------+-----------------+-----------------+------------------+-----------------------------------+--------------------------------------+--------------------------------------+--------------------------------------------------------------------------+--------------------------------------------------------------------------+----------------------------------------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------+-------------------------------+------------------------------+----------------------------+--------------------------------+------------------------------------+---------------------------------------+------------------------------------------------------------------------------------+----------------------------------------------------------------------+----------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------+---------------------------------------------------------------+--------------------------------------------------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------+------------------------------------------------------+---------------------------------------------+-------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------+--------------------------------------------------------------------+----------------------------------------------------+------------------------------------------------+------------------------------------------------------------------------------------------------ ...
# |            AgencyID|AgencyNumber|        AuditEnabled|     CreatedByAuthor|FormHierarchyCollectionID|IncidentOriginID|IncidentTypeID|Locked|                 OID|PatientCareReportNumber| SoftwareCreator|SoftwareName|SoftwareVersion|Status|Validity|__lake_clientId|__lake_dataset| __lake_lastModified|__lake_sourceId|__lake_sourcePipeline|__lake_sourceversion|   __lake_timestamp|__lake_universal_identifier|__lake_universal_integer|__lake_yearMonth|FinishedIncident-FinishedDateTime|FinishedIncident-PerformerID|IncidentIncidentNumberModValue-IncidentNumber|IncidentTime-DispatchNotified|IncidentTime-IncidentTimePSAPModValue-PSAP|Scene-Exposures-ExposureProtectiveEquipments-ProtectiveEquipment|Scene-Exposures-ExposureSuspectedExposureModValue-SuspectedExposure|Scene-Exposures-ExposureTypes-ExposureTypeExposureTypeModValue-NotValue|Scene-Exposures-LicensureID|Scene-GPSLatitude|Scene-GPSLocation|Scene-GPSLongitude|Scene-Response-BeginningOdomReading|Scene-Response-CaresFirstResponderCode|Scene-Response-ComplaintReportDispatch|Scene-Response-CrewMembers-CrewMemberAgencyPerformerIDModValue-LicensureID|Scene-Response-CrewMembers-CrewMemberAgencyPerformerIDModValue-PerformerID|Scene-Response-CrewMembers-CrewMemberCrewMemberLevelModValue-CrewMemberLevel|Scene-Response-CrewMembers-CrewMemberRoles-CrewMemberRoleRoleIDModValue-RoleID|Scene-Response-DispatchDelays-DispatchDelayDelayReasonModValue-DelayReason|Scene-Response-DispatchPriority|Scene-Response-EMSUnitCallSign|Scene-Response-EMSUnitNumber|Scene-Response-EndingOdomReading|Scene-Response-LevelOfCareOfThisUnit|Scene-Response-Patient-AMA-ActiveStatus|Scene-Response-Patient-AdvanceDirectives-AdvanceDirectiveDirectiveModValue-Directive|Scene-Response-Patient-Billing-BillingCMSServiceLevelModValue-NotValue|Scene-Response-Patient-Billing-BillingInsurances-BillingPriority|Scene-Response-Patient-Billing-BillingInsurances-InsuranceCompanyName|Scene-Response-Patient-Billing-BillingPrimaryPaymentMethodModValue-PrimaryPaymentMethod|Scene-Response-Patient-CardiacArrest-AEDPriorToArrivals-PerformedBy|Scene-Response-Patient-CardiacArrest-AEDUsedDuringResuscitation|Scene-Response-Patient-CardiacArrest-CPRPerformeds-CPRPerformedCPRTypeModValue-CPRType|Scene-Response-Patient-CardiacArrest-CPRPriorToArrivals-PerformedBy|Scene-Response-Patient-CardiacArrest-CardiacArrestAEDUsedPriorToArrivalModValue-AEDUsedPriorToArrival|Scene-Response-Patient-CardiacArrest-CardiacArrestCPRProvidedPriorToArrivalModValue-CPRProvidedPriorToArrival|Scene-Response-Patient-CardiacArrest-CardiacArrestCardiacArrestDateModValue-CardiacArrestDate|Scene-Response-Patient-CardiacArrest-CardiacArrestCardiacArrestEtiologyModValue-CardiacArrestEtiology|Scene-Response-Patient-CardiacArrest-CardiacArrestCardiacArrestModValue-CardiacArrest|Scene-Response-Patient-CardiacArrest-CardiacArrestFirstMonitoredRhythmModValue-FirstMonitoredRhythm|Scene-Response-Patient-CardiacArrest-CardiacArrestPatientOutcomeModValue-PatientOutcome|Scene-Response-Patient-CardiacArrest-CardiacArrestWitnesses-CardiacArrestWitnessWitnessModValue-Witness|Scene-Response-Patient-CardiacArrest-CardiacRhythmAtDestinations-CardiacRhythmAtDestinationCardiacRhythmModValue-CardiacRhythm|Scene-Response-Patient-CardiacArrest-CirculationReturneds-CirculationReturnedCirculationReturnedModValue-CirculationReturned|Scene-Response-Patient-CardiacArrest-FirstCPRDate|Scene-Response-Patient-CardiacArrest-MinutesCPRPriorAL|Scene-Response-Patient-CardiacArrest-ROSCTime|Scene-Response-Patient-CardiacArrest-ResuscitationAttemptedby911Responder|Scene-Response-Patient-CardiacArrest-ResuscitationAttempts-ResuscitationAttemptResuscitationAttemptModValue-ResuscitationAttempt|Scene-Response-Patient-CardiacArrest-SustainedROSCEndOfEM|Scene-Response-Patient-CardiacArrest-WhoFirstDefibrillatedthePatient|Scene-Response-Patient-CardiacArrest-WhoInitiatedCPR|Scene-Response-Patient-CurrentMedications-Clinic|Scene-Response-Patient-CurrentMedications-CurrentMedicationMedicationCodeModValue-MedicationCode ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#     27|                                                                             MN|                               20855 Kensington ...|                                           53|                                         AgeUnit_Years|                                                        [PatientCareBarri...|                                          1966-08-23T00:00:00|                                     [jrobinson@imaget...|                                         [EmailAddressType...|                                                     Jack|                                    GenderType_Male|                                         Patient is known ...|                                                  Black|              Patient has demen...|                                          [6313600000]|                                      [PhoneNumberType_...|                                                           [John]|                                                       [Hopkins]|                                                 [6129524689]|                                                                   2410511|                                                          City of Florence|                                                                           17|                                                                         039|                                                                        Lane|                                                                       97439|                                                                         41|                                                                         OR|                                               [false]|                                                                                                                                  [[ProcedureCompli...|                                                                             [1122334455]|                                                                                              [1]|                                                                            [ProcedureRespons...|                                                                        [ProcedurePerform...|                                                                                  [ProcedurePriorTo...|                                                                                [2020-04-06T11:27...|                                                                                              [203923]|                                                                                    [ProcedureSuccess...|                                                   [7.5]|                                                    [Race_White]|                                                                     12412412412412412|                                                                  b5107cc0-16f8-4a3...|                                                                                         [ComplaintType_Ch...|                                                                                               [20]|                                                                                                [ComplaintDuratio...|                                                                                               ChiefComplaintAna...|                                                                                     OrganSystem_Cardi...|                                                                                2020-04-06T11:07:09|                                                                       InitialPatientAcu...|                                                                         PossibleInjurySta...|                                                                                       157229|                                                  79.38|                                            ...
# +--------------------+------------+--------------------+--------------------+-------------------------+----------------+--------------+------+--------------------+-----------------------+----------------+------------+---------------+------+--------+---------------+--------------+--------------------+---------------+---------------------+--------------------+-------------------+---------------------------+------------------------+----------------+---------------------------------+----------------------------+---------------------------------------------+-----------------------------+------------------------------------------+----------------------------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------------------+---------------------------+-----------------+-----------------+------------------+-----------------------------------+--------------------------------------+--------------------------------------+--------------------------------------------------------------------------+--------------------------------------------------------------------------+----------------------------------------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------+-------------------------------+------------------------------+----------------------------+--------------------------------+------------------------------------+---------------------------------------+------------------------------------------------------------------------------------+----------------------------------------------------------------------+----------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------+---------------------------------------------------------------+--------------------------------------------------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------+------------------------------------------------------+---------------------------------------------+-------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------+--------------------------------------------------------------------+----------------------------------------------------+------------------------------------------------+------------------------------------------------------------------------------------------------ ...

# %%
flattened_df.columns
# Out:
# ['AgencyID',
#  'AgencyNumber',
#  'AuditEnabled',
#  'CreatedByAuthor',
#  'FormHierarchyCollectionID',
#  'IncidentOriginID',
#  'IncidentTypeID',
#  'Locked',
#  'OID',
#  'PatientCareReportNumber',
#  'SoftwareCreator',
#  'SoftwareName',
#  'SoftwareVersion',
#  'Status',
#  'Validity',
#  '__lake_clientId',
#  '__lake_dataset',
#  '__lake_lastModified',
#  '__lake_sourceId',
#  '__lake_sourcePipeline',
#  '__lake_sourceversion',
#  '__lake_timestamp',
#  '__lake_universal_identifier',
#  '__lake_universal_integer',
#  '__lake_yearMonth',
#  'FinishedIncident-FinishedDateTime',
#  'FinishedIncident-PerformerID',
#  'IncidentIncidentNumberModValue-IncidentNumber',
#  'IncidentTime-DispatchNotified',
#  'IncidentTime-IncidentTimePSAPModValue-PSAP',
#  'Scene-Exposures-ExposureProtectiveEquipments-ProtectiveEquipment',
#  'Scene-Exposures-ExposureSuspectedExposureModValue-SuspectedExposure',
#  'Scene-Exposures-ExposureTypes-ExposureTypeExposureTypeModValue-NotValue',
#  'Scene-Exposures-LicensureID',
#  'Scene-GPSLatitude',
#  'Scene-GPSLocation',
#  'Scene-GPSLongitude',
#  'Scene-Response-BeginningOdomReading',
#  'Scene-Response-CaresFirstResponderCode',
#  'Scene-Response-ComplaintReportDispatch',
#  'Scene-Response-CrewMembers-CrewMemberAgencyPerformerIDModValue-LicensureID',
#  'Scene-Response-CrewMembers-CrewMemberAgencyPerformerIDModValue-PerformerID',
#  'Scene-Response-CrewMembers-CrewMemberCrewMemberLevelModValue-CrewMemberLevel',
#  'Scene-Response-CrewMembers-CrewMemberRoles-CrewMemberRoleRoleIDModValue-RoleID',
#  'Scene-Response-DispatchDelays-DispatchDelayDelayReasonModValue-DelayReason',
#  'Scene-Response-DispatchPriority',
#  'Scene-Response-EMSUnitCallSign',
#  'Scene-Response-EMSUnitNumber',
#  'Scene-Response-EndingOdomReading',
#  'Scene-Response-LevelOfCareOfThisUnit',
#  'Scene-Response-Patient-AMA-ActiveStatus',
#  'Scene-Response-Patient-AdvanceDirectives-AdvanceDirectiveDirectiveModValue-Directive',
#  'Scene-Response-Patient-Billing-BillingCMSServiceLevelModValue-NotValue',
#  'Scene-Response-Patient-Billing-BillingInsurances-BillingPriority',
#  'Scene-Response-Patient-Billing-BillingInsurances-InsuranceCompanyName',
#  'Scene-Response-Patient-Billing-BillingPrimaryPaymentMethodModValue-PrimaryPaymentMethod',
#  'Scene-Response-Patient-CardiacArrest-AEDPriorToArrivals-PerformedBy',
#  'Scene-Response-Patient-CardiacArrest-AEDUsedDuringResuscitation',
#  'Scene-Response-Patient-CardiacArrest-CPRPerformeds-CPRPerformedCPRTypeModValue-CPRType',
#  'Scene-Response-Patient-CardiacArrest-CPRPriorToArrivals-PerformedBy',
#  'Scene-Response-Patient-CardiacArrest-CardiacArrestAEDUsedPriorToArrivalModValue-AEDUsedPriorToArrival',
#  'Scene-Response-Patient-CardiacArrest-CardiacArrestCPRProvidedPriorToArrivalModValue-CPRProvidedPriorToArrival',
#  'Scene-Response-Patient-CardiacArrest-CardiacArrestCardiacArrestDateModValue-CardiacArrestDate',
#  'Scene-Response-Patient-CardiacArrest-CardiacArrestCardiacArrestEtiologyModValue-CardiacArrestEtiology',
#  'Scene-Response-Patient-CardiacArrest-CardiacArrestCardiacArrestModValue-CardiacArrest',
#  'Scene-Response-Patient-CardiacArrest-CardiacArrestFirstMonitoredRhythmModValue-FirstMonitoredRhythm',
#  'Scene-Response-Patient-CardiacArrest-CardiacArrestPatientOutcomeModValue-PatientOutcome',
#  'Scene-Response-Patient-CardiacArrest-CardiacArrestWitnesses-CardiacArrestWitnessWitnessModValue-Witness',
#  'Scene-Response-Patient-CardiacArrest-CardiacRhythmAtDestinations-CardiacRhythmAtDestinationCardiacRhythmModValue-CardiacRhythm',
#  'Scene-Response-Patient-CardiacArrest-CirculationReturneds-CirculationReturnedCirculationReturnedModValue-CirculationReturned',
#  'Scene-Response-Patient-CardiacArrest-FirstCPRDate',
#  'Scene-Response-Patient-CardiacArrest-MinutesCPRPriorAL',
#  'Scene-Response-Patient-CardiacArrest-ROSCTime',
#  'Scene-Response-Patient-CardiacArrest-ResuscitationAttemptedby911Responder',
#  'Scene-Response-Patient-CardiacArrest-ResuscitationAttempts-ResuscitationAttemptResuscitationAttemptModValue-ResuscitationAttempt',
#  'Scene-Response-Patient-CardiacArrest-SustainedROSCEndOfEM',
#  'Scene-Response-Patient-CardiacArrest-WhoFirstDefibrillatedthePatient',
#  'Scene-Response-Patient-CardiacArrest-WhoInitiatedCPR',
#  'Scene-Response-Patient-CurrentMedications-Clinic',
#  'Scene-Response-Patient-CurrentMedications-CurrentMedicationMedicationCodeModValue-MedicationCode',
#  'Scene-Response-Patient-CurrentMedications-DateFilled',
#  'Scene-Response-Patient-CurrentMedications-DosageFrequency',
#  'Scene-Response-Patient-CurrentMedications-Dose',
#  'Scene-Response-Patient-CurrentMedications-DoseUnit',
#  'Scene-Response-Patient-CurrentMedications-MedicationDiscrepancy',
#  'Scene-Response-Patient-CurrentMedications-Pharmacy',
#  'Scene-Response-Patient-CurrentMedications-PractitionerType',
#  'Scene-Response-Patient-CurrentMedications-PrescribingDoctor',
#  'Scene-Response-Patient-CurrentMedications-ProviderAdditionalNote',
#  'Scene-Response-Patient-Disposition-AdditionalTransportModes-AdditionalTransportModeTransportModeModValue-TransportMode',
#  'Scene-Response-Patient-Disposition-DestinationReasons-DestinationReasonDestinationReasonModValue-DestinationReason',
#  'Scene-Response-Patient-Disposition-DispositionAddress-CityGNI',
#  'Scene-Response-Patient-Disposition-DispositionAddress-CityName',
#  'Scene-Response-Patient-Disposition-DispositionAddress-CountryCode',
#  'Scene-Response-Patient-Disposition-DispositionAddress-CountryName',
#  'Scene-Response-Patient-Disposition-DispositionAddress-DispositionAddressCountyGNISModValue-CountyGNIS',
#  'Scene-Response-Patient-Disposition-DispositionAddress-DispositionAddressCountyGNISModValue-CountyName',
#  'Scene-Response-Patient-Disposition-DispositionAddress-DispositionAddressPostalCodeModValue-PostalCode',
#  'Scene-Response-Patient-Disposition-DispositionAddress-DispositionAddressStateGNISModValue-StateGNIS',
#  'Scene-Response-Patient-Disposition-DispositionAddress-DispositionAddressStateGNISModValue-StateName',
#  'Scene-Response-Patient-Disposition-DispositionDestinationCodeModValue-DestinationCode',
#  'Scene-Response-Patient-Disposition-DispositionDestinationNameModValue-DestinationName',
#  'Scene-Response-Patient-Disposition-DispositionDestinationTypeModValue-DestinationType',
#  'Scene-Response-Patient-Disposition-DispositionEMSTransportMethodModValue-EMSTransportMethod',
#  'Scene-Response-Patient-Disposition-DispositionHospitalDesignationModValue-HospitalDesignation',
#  'Scene-Response-Patient-Disposition-DispositionNumberOfPatientsTransportedModValue-NumberOfPatientsTransported',
#  'Scene-Response-Patient-Disposition-DispositionPatientConditionAtDestinationModValue-PatientConditionAtDestination',
#  'Scene-Response-Patient-Disposition-DispositionTransportModeFromSceneModValue-TransportModeFromScene',
#  'Scene-Response-Patient-Disposition-PatientDisposition',
#  'Scene-Response-Patient-EMSPatientID',
#  'Scene-Response-Patient-EnvironmentAllergies-EnvironmentAllergy1',
#  'Scene-Response-Patient-Exams-AbdomenExams-AbdomenAssessments-AbdomenAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-AbdomenExams-FindingLocation',
#  'Scene-Response-Patient-Exams-ChestExam-ChestAssessments-ChestAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-ExamCrewMemberIDModValue-LicensureID',
#  'Scene-Response-Patient-Exams-ExamExamDateTimeModValue-ExamDateTime',
#  'Scene-Response-Patient-Exams-ExtremityExams-ExtremityAssessments-ExtremityAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-ExtremityExams-FindingLocation',
#  'Scene-Response-Patient-Exams-EyeExams-EyeAssessments-EyeAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-EyeExams-FindingLocation',
#  'Scene-Response-Patient-Exams-FaceExam-FaceAssessments-FaceAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-HeadExam-HeadAssessments-HeadAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-MentalExam-MentalAssessments-MentalAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-NeckExam-NeckAssessments-NeckAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-NeurologicalExam-NeurologicalAssessments-NeurologicalAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-PelvisExam-PelvisAssessments-PelvisAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-SkinExam-SkinAssessments-SkinAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-Exams-SpineExams-FindingLocation',
#  'Scene-Response-Patient-Exams-SpineExams-SpineAssessments-SpineAssessmentAssessmentModValue-Assessment',
#  'Scene-Response-Patient-IsMember',
#  'Scene-Response-Patient-MedSurgHistories-MedSurgHistoryProcedureCodeModValue-ProcedureCode',
#  'Scene-Response-Patient-MedicalHistoryObtaineds-HistoryObtainedFrom',
#  'Scene-Response-Patient-MedicationAllergies-MedicationAllergyMedicationAllergyModValue-MedicationAllergyCombined',
#  'Scene-Response-Patient-Medications-AdministeredRoute',
#  'Scene-Response-Patient-Medications-MedicationAdministeredPriorToEMSCareModValue-AdministeredPriorToEMSCare',
#  'Scene-Response-Patient-Medications-MedicationComplications-MedicationComplicationComplicationModValue-Complication',
#  'Scene-Response-Patient-Medications-MedicationCrewMemberIDModValue-LicensureID',
#  'Scene-Response-Patient-Medications-MedicationDosageModValue-Dosage',
#  'Scene-Response-Patient-Medications-MedicationDosageUnitModValue-DosageUnit',
#  'Scene-Response-Patient-Medications-MedicationMedicationDateTimeModValue-MedicationDateTime',
#  'Scene-Response-Patient-Medications-MedicationMedicationGivenModValue-MedicationGiven',
#  'Scene-Response-Patient-Medications-MedicationResponseToMedicationModValue-ResponseToMedication',
#  'Scene-Response-Patient-Medications-MonitorImport',
#  'Scene-Response-Patient-PatientAddress-CityGNIS',
#  'Scene-Response-Patient-PatientAddress-CityName',
#  'Scene-Response-Patient-PatientAddress-CountryCode',
#  'Scene-Response-Patient-PatientAddress-PatientAddressCountyGNISModValue-CountyGNIS',
#  'Scene-Response-Patient-PatientAddress-PatientAddressCountyGNISModValue-CountyName',
#  'Scene-Response-Patient-PatientAddress-PatientAddressPostalCodeModValue-PostalCode',
#  'Scene-Response-Patient-PatientAddress-PatientAddressStateGNISModValue-StateGNIS',
#  'Scene-Response-Patient-PatientAddress-PatientAddressStateGNISModValue-StateName',
#  'Scene-Response-Patient-PatientAddress-StreetAddress',
#  'Scene-Response-Patient-PatientAgeModValue-Age',
#  'Scene-Response-Patient-PatientAgeUnitsModValue-AgeUnit',
#  'Scene-Response-Patient-PatientBarriers-PatientBarrierBarrierModValue-Barrier',
#  'Scene-Response-Patient-PatientDateOfBirthModValue-DateOfBirth',
#  'Scene-Response-Patient-PatientEmailAddresses-EmailAddress',
#  'Scene-Response-Patient-PatientEmailAddresses-EmailAddressType',
#  'Scene-Response-Patient-PatientFirstNameModValue-FirstName',
#  'Scene-Response-Patient-PatientGenderModValue-Gender',
#  'Scene-Response-Patient-PatientHistory-OtherPastMedicalHistory',
#  'Scene-Response-Patient-PatientLastNameModValue-LastName',
#  'Scene-Response-Patient-PatientNote',
#  'Scene-Response-Patient-PatientPhoneNumbers-PhoneNumber',
#  'Scene-Response-Patient-PatientPhoneNumbers-PhoneNumberType',
#  'Scene-Response-Patient-PatientPractitioners-PractitionerFirstName',
#  'Scene-Response-Patient-PatientPractitioners-PractitionerLastName',
#  'Scene-Response-Patient-PatientPractitioners-PractitionerPhone',
#  'Scene-Response-Patient-PatientPrimaryKin-PatientPrimaryKinAddress-CityGNIS',
#  'Scene-Response-Patient-PatientPrimaryKin-PatientPrimaryKinAddress-CityName',
#  'Scene-Response-Patient-PatientPrimaryKin-PatientPrimaryKinAddress-CountryCode',
#  'Scene-Response-Patient-PatientPrimaryKin-PatientPrimaryKinAddress-CountyGNIS',
#  'Scene-Response-Patient-PatientPrimaryKin-PatientPrimaryKinAddress-CountyName',
#  'Scene-Response-Patient-PatientPrimaryKin-PatientPrimaryKinAddress-PostalCode',
#  'Scene-Response-Patient-PatientPrimaryKin-PatientPrimaryKinAddress-StateGNIS',
#  'Scene-Response-Patient-PatientPrimaryKin-PatientPrimaryKinAddress-StateName',
#  'Scene-Response-Patient-PatientProcedures-MonitorImport',
#  'Scene-Response-Patient-PatientProcedures-PatientProcedureComplications-PatientProcedureComplicationProcedureComplicationModValue-ProcedureComplication',
#  'Scene-Response-Patient-PatientProcedures-PatientProcedureCrewMemberIDModValue-LicensureID',
#  'Scene-Response-Patient-PatientProcedures-PatientProcedureNumberOfAttemptsModValue-NumberOfAttempt',
#  'Scene-Response-Patient-PatientProcedures-PatientProcedurePatientResponseModValue-PatientResponse',
#  'Scene-Response-Patient-PatientProcedures-PatientProcedurePerformerRoleModValue-PerformerRole',
#  'Scene-Response-Patient-PatientProcedures-PatientProcedurePriorToEMSUnitCareModValue-PriorToEMSUnitCare',
#  'Scene-Response-Patient-PatientProcedures-PatientProcedureProcedureDateTimeModValue-ProcedureDateTime',
#  'Scene-Response-Patient-PatientProcedures-PatientProcedureProcedurePerformedModValue-ProcedurePerformed',
#  'Scene-Response-Patient-PatientProcedures-PatientProcedureProcedureSuccessfulModValue-ProcedureSuccessful',
#  'Scene-Response-Patient-PatientProcedures-SizeOfEquipment',
#  'Scene-Response-Patient-PatientRaces-PatientRaceRaceModValue-Race',
#  'Scene-Response-Patient-PatientResponse-PatientResponseCrewMemberIDModValue-LicensureID',
#  'Scene-Response-Patient-PatientResponse-PatientResponseCrewMemberIDModValue-PerformerID',
#  'Scene-Response-Patient-PatientSituation-PatientComplaints-PatientComplaintComplaintTypeModValue-ComplaintType',
#  'Scene-Response-Patient-PatientSituation-PatientComplaints-PatientComplaintDurationModValue-Duration',
#  'Scene-Response-Patient-PatientSituation-PatientComplaints-PatientComplaintDurationTimeUnitsModValue-DurationTimeUnit',
#  'Scene-Response-Patient-PatientSituation-PatientSituationComplaintAnatomicLocationModValue-ComplaintAnatomicLocation',
#  'Scene-Response-Patient-PatientSituation-PatientSituationComplaintOrganSystemModValue-ComplaintOrganSystem',
#  'Scene-Response-Patient-PatientSituation-PatientSituationIncidentOnsetDateModValue-IncidentOnsetDate',
#  'Scene-Response-Patient-PatientSituation-PatientSituationInitialAcuityModValue-InitialAcuity',
#  'Scene-Response-Patient-PatientSituation-PatientSituationPossibleInjuryModValue-PossibleInjury',
#  'Scene-Response-Patient-PatientSituation-PatientSituationPrimarySymptomModValue-PrimarySymptom',
#  'Scene-Response-Patient-PatientWeightKGModValue-WeightKG',
#  'Scene-Response-Patient-ProviderActions-BuiltInPowerToolId',
#  'Scene-Response-Patient-ProviderActions-ProviderActionActivities-ExamID',
#  'Scene-Response-Patient-ProviderPrimaryImpression-ProviderPrimaryImpressionImpressionModValue-Impression',
#  'Scene-Response-Patient-SSN',
#  'Scene-Response-Patient-Signatures-FileType',
#  'Scene-Response-Patient-Signatures-FirstName',
#  'Scene-Response-Patient-Signatures-LastName',
#  'Scene-Response-Patient-Signatures-LicensureID',
#  'Scene-Response-Patient-Signatures-LockedStatus',
#  'Scene-Response-Patient-Signatures-ParagraphText',
#  'Scene-Response-Patient-Signatures-PerformerID',
#  'Scene-Response-Patient-Signatures-PersonSigning',
#  'Scene-Response-Patient-Signatures-SignatureDate',
#  'Scene-Response-Patient-Signatures-SignatureLanguageID',
#  'Scene-Response-Patient-Signatures-SignatureReasons-Reason',
#  'Scene-Response-Patient-Signatures-Status',
#  'Scene-Response-Patient-Signatures-TypeOfPatientRepresentative',
#  'Scene-Response-Patient-VeteranStatus',
#  'Scene-Response-Patient-Vitals-ECGCardiacRhythms-ECGCardiacRhythmCardiacRhythmModValue-CardiacRhythm',
#  'Scene-Response-Patient-Vitals-MeanArterialPressure',
#  'Scene-Response-Patient-Vitals-MonitorImport',
#  'Scene-Response-Patient-Vitals-VitalsBPMethodModValue-BPMethod',
#  'Scene-Response-Patient-Vitals-VitalsDBPModValue-DBP',
#  'Scene-Response-Patient-Vitals-VitalsGCSEyeModValue-GCSEye',
#  'Scene-Response-Patient-Vitals-VitalsGCSMotorModValue-GCSMotor',
#  'Scene-Response-Patient-Vitals-VitalsGCSTotalModValue-GCSTotal',
#  'Scene-Response-Patient-Vitals-VitalsGCSVerbalModValue-GCSVerbal',
#  'Scene-Response-Patient-Vitals-VitalsLevelOfResponseModValue-LevelOfResponse',
#  'Scene-Response-Patient-Vitals-VitalsObtainedPriorToEMSCareModValue-NotValue',
#  'Scene-Response-Patient-Vitals-VitalsPulseOximetryModValue-PulseOximetry',
#  'Scene-Response-Patient-Vitals-VitalsPulseRateModValue-PulseRate',
#  'Scene-Response-Patient-Vitals-VitalsRTSModValue-RT',
#  'Scene-Response-Patient-Vitals-VitalsRespiratoryRateModValue-RespiratoryRate',
#  'Scene-Response-Patient-Vitals-VitalsSBPModValue-SBP',
#  'Scene-Response-Patient-Vitals-VitalsVitalsDateTimeModValue-VitalsDateTime',
#  'Scene-Response-PrimaryRoleOfUnit',
#  'Scene-Response-ResponseEMDPerformedModValue-EMDPerformed',
#  'Scene-Response-ResponseEMSAgencyNameModValue-EMSAgencyName',
#  'Scene-Response-ResponseEMSResponseNumberModValue-EMSResponseNumber',
#  'Scene-Response-ResponseFirstEMSUnitOnSceneModValue-FirstEMSUnitOnScene',
#  'Scene-Response-ResponseModeToScene',
#  'Scene-Response-ResponseModes-ResponseModeResponseModeModValue-ResponseMode',
#  'Scene-Response-ResponseTime-ResponseTimeArrivedAtPatientModValue-ArrivedAtPatient',
#  'Scene-Response-ResponseTime-ResponseTimeDestinationPatientTransferOfCareModValue-DestinationPatientTransferOfCare',
#  'Scene-Response-ResponseTime-ResponseTimePatientArrivedAtDestinationModValue-PatientArrivedAtDestination',
#  'Scene-Response-ResponseTime-ResponseTimeUnitArrivedOnSceneModValue-UnitArrivedOnScene',
#  'Scene-Response-ResponseTime-ResponseTimeUnitEnrouteModValue-UnitEnroute',
#  'Scene-Response-ResponseTime-ResponseTimeUnitLeftSceneModValue-UnitLeftScene',
#  'Scene-Response-ResponseTime-UnitBackInService',
#  'Scene-Response-ResponseTime-UnitNotifiedByDispatch',
#  'Scene-Response-TypeOfServiceRequested',
#  'Scene-Response-UnitType',
#  'Scene-SceneAddress-CountryCode',
#  'Scene-SceneAddress-SceneAddressCityGNISModValue-CityGNIS',
#  'Scene-SceneAddress-SceneAddressCityGNISModValue-CityName',
#  'Scene-SceneAddress-SceneAddressCountyGNISModValue-CountyGNIS',
#  'Scene-SceneAddress-SceneAddressCountyGNISModValue-CountyName',
#  'Scene-SceneAddress-SceneAddressPostalCodeModValue-PostalCode',
#  'Scene-SceneAddress-SceneAddressStateGNISModValue-StateGNIS',
#  'Scene-SceneAddress-SceneAddressStateGNISModValue-StateName',
#  'Scene-SceneAddress-SceneAddressStreetAddressModValue-StreetAddress',
#  'Scene-SceneLocationTypeModValue-LocationType',
#  'Scene-SceneNumberOfPatientsAtSceneModValue-NumberOfPatientsAtScene']

# %%
flattened_df.count()
# Out:
# 1

# %%
for column in flattened_df.columns:
    first_value = flattened_df.select(col(column)).first()[0]
    
    if isinstance(first_value, list):
        print("column name",column)
        print("value of the columns",first_value)
# Out:
# column name Scene-Exposures-ExposureProtectiveEquipments-ProtectiveEquipment
# value of the columns [['PersonalProtectiveEquipmentUsage_EyeProtection', 'PersonalProtectiveEquipmentUsage_Gloves', 'PersonalProtectiveEquipmentUsage_MaskN95']]
# column name Scene-Exposures-ExposureSuspectedExposureModValue-SuspectedExposure
# value of the columns ['EMSWorkRelatedHarmModifier_No']
# column name Scene-Exposures-ExposureTypes-ExposureTypeExposureTypeModValue-NotValue
# value of the columns [['TypeOfWorkRelatedHarmModifier_NotValue_NotApplicable']]
# column name Scene-Exposures-LicensureID
# value of the columns ['1122334455']
# column name Scene-Response-CrewMembers-CrewMemberAgencyPerformerIDModValue-LicensureID
# value of the columns ['1122334455', '214']
# column name Scene-Response-CrewMembers-CrewMemberAgencyPerformerIDModValue-PerformerID
# value of the columns ['ed8ad2d5-f0a4-447f-b3ef-850e40ec9f7b', '2724f3bd-c30d-4d7f-8b55-685eca6b2ae2']
# column name Scene-Response-CrewMembers-CrewMemberCrewMemberLevelModValue-CrewMemberLevel
# value of the columns ['CrewMemberCertificationLevel_EMTParamedic', 'CrewMemberCertificationLevel_EMTIntermediate']
# column name Scene-Response-CrewMembers-CrewMemberRoles-CrewMemberRoleRoleIDModValue-RoleID
# value of the columns [['CrewMemberResponseRole_PrimaryPatientCaregiverAtScene'], ['CrewMemberResponseRole_DriverPilotResponse']]
# column name Scene-Response-DispatchDelays-DispatchDelayDelayReasonModValue-DelayReason
# value of the columns ['DispatchDelayType_NoneNoDelay']
# column name Scene-Response-Patient-AdvanceDirectives-AdvanceDirectiveDirectiveModValue-Directive
# value of the columns ['PatientAdvanceDirective_OtherHealthcareAdvancedDirectiveForm', 'PatientAdvanceDirective_LivingWill', 'PatientAdvanceDirective_None']
# column name Scene-Response-Patient-Billing-BillingInsurances-BillingPriority
# value of the columns [None, 'InsuranceCompanyBillingPriority_Primary', 'InsuranceCompanyBillingPriority_Secondary']
# column name Scene-Response-Patient-Billing-BillingInsurances-InsuranceCompanyName
# value of the columns ['Medicare', 'Primary Insurance', 'Secondary']
# column name Scene-Response-Patient-CardiacArrest-AEDPriorToArrivals-PerformedBy
# value of the columns ['PriorToEMSArrivalAEDUser_LayPersonNonFamily']
# column name Scene-Response-Patient-CardiacArrest-CPRPerformeds-CPRPerformedCPRTypeModValue-CPRType
# value of the columns ['CPRType_CompressionsContinuous', 'CPRType_VentilationBagValveMask']
# column name Scene-Response-Patient-CardiacArrest-CPRPriorToArrivals-PerformedBy
# value of the columns ['PersonProvidingPriorToEMSCPRType_FamilyMember']
# column name Scene-Response-Patient-CardiacArrest-CardiacArrestWitnesses-CardiacArrestWitnessWitnessModValue-Witness
# value of the columns ['ArrestWitnessType_WitnessedbyFamilyMember']
# column name Scene-Response-Patient-CardiacArrest-CardiacRhythmAtDestinations-CardiacRhythmAtDestinationCardiacRhythmModValue-CardiacRhythm
# value of the columns ['DestinationArrivalCardiacRhythm_SinusTachycardia']
# column name Scene-Response-Patient-CardiacArrest-CirculationReturneds-CirculationReturnedCirculationReturnedModValue-CirculationReturned
# value of the columns ['SpontaneousCirculationReturnedStatus_YesPriortoArrivalattheED']
# column name Scene-Response-Patient-CardiacArrest-ResuscitationAttempts-ResuscitationAttemptResuscitationAttemptModValue-ResuscitationAttempt
# value of the columns ['EMSResuscitationAttempt_InitiatedChestCompressions', 'EMSResuscitationAttempt_AttemptedVentilation']
# column name Scene-Response-Patient-CurrentMedications-Clinic
# value of the columns [None, 'Dean Clinic', None, None]
# column name Scene-Response-Patient-CurrentMedications-CurrentMedicationMedicationCodeModValue-MedicationCode
# value of the columns [599286, 274023, 311870, 388770]
# column name Scene-Response-Patient-CurrentMedications-DateFilled
# value of the columns [None, '2018-04-25T00:00:00', None, None]
# column name Scene-Response-Patient-CurrentMedications-DosageFrequency
# value of the columns [None, 'PatientDosageFrequency_AsNeeded', None, None]
# column name Scene-Response-Patient-CurrentMedications-Dose
# value of the columns [0.0, 2.0, 0.0, None]
# column name Scene-Response-Patient-CurrentMedications-DoseUnit
# value of the columns [None, 'CurrentMedicationDosageUnit_puffs', None, None]
# column name Scene-Response-Patient-CurrentMedications-MedicationDiscrepancy
# value of the columns [None, 'PatientMedicationDiscrepancy_No', None, None]
# column name Scene-Response-Patient-CurrentMedications-Pharmacy
# value of the columns [None, 'Walgreens', None, None]
# column name Scene-Response-Patient-CurrentMedications-PractitionerType
# value of the columns [None, 'Pulmonary', None, None]
# column name Scene-Response-Patient-CurrentMedications-PrescribingDoctor
# value of the columns [None, 'Smith', None, None]
# column name Scene-Response-Patient-CurrentMedications-ProviderAdditionalNote
# value of the columns [None, 'Pt uses about 3 times per week.', None, None]
# column name Scene-Response-Patient-Disposition-AdditionalTransportModes-AdditionalTransportModeTransportModeModValue-TransportMode
# value of the columns ['TransportModeDescriptor_LightsAndSirens']
# column name Scene-Response-Patient-Disposition-DestinationReasons-DestinationReasonDestinationReasonModValue-DestinationReason
# value of the columns ['DestinationChoiceReason_ClosestFacility']
# column name Scene-Response-Patient-EnvironmentAllergies-EnvironmentAllergy1
# value of the columns [47345]
# column name Scene-Response-Patient-Exams-AbdomenExams-AbdomenAssessments-AbdomenAssessmentAssessmentModValue-Assessment
# value of the columns [[['AbdomenAssessmentObservation_Normal'], ['AbdomenAssessmentObservation_Normal'], ['AbdomenAssessmentObservation_Normal'], ['AbdomenAssessmentObservation_Normal'], ['AbdomenAssessmentObservation_Normal'], ['AbdomenAssessmentObservation_Normal']]]
# column name Scene-Response-Patient-Exams-AbdomenExams-FindingLocation
# value of the columns [['AbdominalAssessmentFindingLocation_Generalized', 'AbdominalAssessmentFindingLocation_LeftLowerQuadrant', 'AbdominalAssessmentFindingLocation_LeftUpperQuadrant', 'AbdominalAssessmentFindingLocation_Periumbilical', 'AbdominalAssessmentFindingLocation_RightLowerQuadrant', 'AbdominalAssessmentFindingLocation_RightUpperQuadrant']]
# column name Scene-Response-Patient-Exams-ChestExam-ChestAssessments-ChestAssessmentAssessmentModValue-Assessment
# value of the columns [['ChestLungAssessmentObservation_Normal', 'ChestLungAssessmentObservation_BreathSoundsNormalLeft', 'ChestLungAssessmentObservation_BreathSoundsNormalRight', 'ChestLungAssessmentObservation_BreathSoundsEqual']]
# column name Scene-Response-Patient-Exams-ExamCrewMemberIDModValue-LicensureID
# value of the columns ['1122334455']
# column name Scene-Response-Patient-Exams-ExamExamDateTimeModValue-ExamDateTime
# value of the columns ['2020-04-06T11:27:09']
# column name Scene-Response-Patient-Exams-ExtremityExams-ExtremityAssessments-ExtremityAssessmentAssessmentModValue-Assessment
# value of the columns [[['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal'], ['ExtremitiesAssessmentObservation_Normal']]]
# column name Scene-Response-Patient-Exams-ExtremityExams-FindingLocation
# value of the columns [['ExtremityAssessmentFindingLocation_AnkleLeft', 'ExtremityAssessmentFindingLocation_AnkleRight', 'ExtremityAssessmentFindingLocation_ArmUpperLeft', 'ExtremityAssessmentFindingLocation_ArmUpperRight', 'ExtremityAssessmentFindingLocation_ElbowLeft', 'ExtremityAssessmentFindingLocation_ElbowRight', 'ExtremityAssessmentFindingLocation_Finger2ndIndexLeft', 'ExtremityAssessmentFindingLocation_Finger2ndIndexRight', 'ExtremityAssessmentFindingLocation_Finger3rdMiddleLeft', 'ExtremityAssessmentFindingLocation_Finger3rdMiddleRight', 'ExtremityAssessmentFindingLocation_Finger4thRingLeft', 'ExtremityAssessmentFindingLocation_Finger4thRingRight', 'ExtremityAssessmentFindingLocation_Finger5thSmallestLeft', 'ExtremityAssessmentFindingLocation_Finger5thSmallestRight', 'ExtremityAssessmentFindingLocation_FootDorsalLeft', 'ExtremityAssessmentFindingLocation_FootDorsalRight', 'ExtremityAssessmentFindingLocation_FootPlantarLeft', 'ExtremityAssessmentFindingLocation_FootPlantarRight', 'ExtremityAssessmentFindingLocation_ForearmLeft', 'ExtremityAssessmentFindingLocation_ForearmRight', 'ExtremityAssessmentFindingLocation_HandDorsalLeft', 'ExtremityAssessmentFindingLocation_HandDorsalRight', 'ExtremityAssessmentFindingLocation_HandPalmLeft', 'ExtremityAssessmentFindingLocation_HandPalmRight', 'ExtremityAssessmentFindingLocation_HipLeft', 'ExtremityAssessmentFindingLocation_HipRight', 'ExtremityAssessmentFindingLocation_KneeLeft', 'ExtremityAssessmentFindingLocation_KneeRight', 'ExtremityAssessmentFindingLocation_LegLowerLeft', 'ExtremityAssessmentFindingLocation_LegLowerRight', 'ExtremityAssessmentFindingLocation_LegUpperLeft', 'ExtremityAssessmentFindingLocation_LegUpperRight', 'ExtremityAssessmentFindingLocation_ShoulderLeft', 'ExtremityAssessmentFindingLocation_ShoulderRight', 'ExtremityAssessmentFindingLocation_ThumbLeft', 'ExtremityAssessmentFindingLocation_ThumbRight', 'ExtremityAssessmentFindingLocation_Toe1stBigLeft', 'ExtremityAssessmentFindingLocation_Toe1stBigRight', 'ExtremityAssessmentFindingLocation_Toe2ndLeft', 'ExtremityAssessmentFindingLocation_Toe2ndRight', 'ExtremityAssessmentFindingLocation_Toe3rdLeft', 'ExtremityAssessmentFindingLocation_Toe3rdRight', 'ExtremityAssessmentFindingLocation_Toe4thLeft', 'ExtremityAssessmentFindingLocation_Toe4thRight', 'ExtremityAssessmentFindingLocation_Toe5thSmallestLeft', 'ExtremityAssessmentFindingLocation_Toe5thSmallestRight', 'ExtremityAssessmentFindingLocation_WristLeft', 'ExtremityAssessmentFindingLocation_WristRight']]
# column name Scene-Response-Patient-Exams-EyeExams-EyeAssessments-EyeAssessmentAssessmentModValue-Assessment
# value of the columns [[['EyeAssessment_Reactive'], ['EyeAssessment_Reactive'], ['EyeAssessment_Reactive']]]
# column name Scene-Response-Patient-Exams-EyeExams-FindingLocation
# value of the columns [['EyeAssessmentFindingLocation_Bilateral', 'EyeAssessmentFindingLocation_Left', 'EyeAssessmentFindingLocation_Right']]
# column name Scene-Response-Patient-Exams-FaceExam-FaceAssessments-FaceAssessmentAssessmentModValue-Assessment
# value of the columns [['FaceAssessment_Normal']]
# column name Scene-Response-Patient-Exams-HeadExam-HeadAssessments-HeadAssessmentAssessmentModValue-Assessment
# value of the columns [['HeadAssessment_Normal']]
# column name Scene-Response-Patient-Exams-MentalExam-MentalAssessments-MentalAssessmentAssessmentModValue-Assessment
# value of the columns [['MentalStatusAssessment_NormalBaselineforPatient']]
# column name Scene-Response-Patient-Exams-NeckExam-NeckAssessments-NeckAssessmentAssessmentModValue-Assessment
# value of the columns [['NeckAssessmentObservation_Normal']]
# column name Scene-Response-Patient-Exams-NeurologicalExam-NeurologicalAssessments-NeurologicalAssessmentAssessmentModValue-Assessment
# value of the columns [['NeurologicalAssessmentObservation_NormalBaselineforPatient']]
# column name Scene-Response-Patient-Exams-PelvisExam-PelvisAssessments-PelvisAssessmentAssessmentModValue-Assessment
# value of the columns [['PelvisGenitourinaryAssessmentObservation_Normal']]
# column name Scene-Response-Patient-Exams-SkinExam-SkinAssessments-SkinAssessmentAssessmentModValue-Assessment
# value of the columns [['SkinAssessment_Normal']]
# column name Scene-Response-Patient-Exams-SpineExams-FindingLocation
# value of the columns [['BackSpineAssessmentFindingLocation_BackGeneral', 'BackSpineAssessmentFindingLocation_CervicalLeft', 'BackSpineAssessmentFindingLocation_CervicalMidline', 'BackSpineAssessmentFindingLocation_CervicalRight', 'BackSpineAssessmentFindingLocation_CrushInjury', 'BackSpineAssessmentFindingLocation_LumbarLeft', 'BackSpineAssessmentFindingLocation_LumbarMidline', 'BackSpineAssessmentFindingLocation_LumbarRight', 'BackSpineAssessmentFindingLocation_SacralLeft', 'BackSpineAssessmentFindingLocation_SacralMidline', 'BackSpineAssessmentFindingLocation_SacralRight', 'BackSpineAssessmentFindingLocation_ThoracicLeft', 'BackSpineAssessmentFindingLocation_ThoracicMidline', 'BackSpineAssessmentFindingLocation_ThoracicRight']]
# column name Scene-Response-Patient-Exams-SpineExams-SpineAssessments-SpineAssessmentAssessmentModValue-Assessment
# value of the columns [[['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal'], ['BackSpineAssessmentObservation_Normal']]]
# column name Scene-Response-Patient-MedSurgHistories-MedSurgHistoryProcedureCodeModValue-ProcedureCode
# value of the columns [7589, 86332, 24335]
# column name Scene-Response-Patient-MedicalHistoryObtaineds-HistoryObtainedFrom
# value of the columns ['PersonMedicalHistoryObtainedFromType_Patient']
# column name Scene-Response-Patient-MedicationAllergies-MedicationAllergyMedicationAllergyModValue-MedicationAllergyCombined
# value of the columns ['r_8905', 'i_38167', 'r_350785']
# column name Scene-Response-Patient-Medications-AdministeredRoute
# value of the columns ['MedicationAdministrationRoute_Inhalation', 'MedicationAdministrationRoute_IntravenousIV', 'MedicationAdministrationRoute_IntravenousIV', 'MedicationAdministrationRoute_IntravenousIV', 'MedicationAdministrationRoute_IntravenousIV']
# column name Scene-Response-Patient-Medications-MedicationAdministeredPriorToEMSCareModValue-AdministeredPriorToEMSCare
# value of the columns ['MedicationPriorToEMSCareStatus_No', 'MedicationPriorToEMSCareStatus_No', 'MedicationPriorToEMSCareStatus_No', 'MedicationPriorToEMSCareStatus_No', 'MedicationPriorToEMSCareStatus_No']
# column name Scene-Response-Patient-Medications-MedicationComplications-MedicationComplicationComplicationModValue-Complication
# value of the columns [['MedicationComplicationType_None'], ['MedicationComplicationType_None'], ['MedicationComplicationType_None'], ['MedicationComplicationType_None'], ['MedicationComplicationType_None']]
# column name Scene-Response-Patient-Medications-MedicationCrewMemberIDModValue-LicensureID
# value of the columns ['1122334455', '1122334455', '1122334455', '1122334455', '1122334455']
# column name Scene-Response-Patient-Medications-MedicationDosageModValue-Dosage
# value of the columns [15.0, 1.0, 1.0, 1.0, 1.0]
# column name Scene-Response-Patient-Medications-MedicationDosageUnitModValue-DosageUnit
# value of the columns ['MedicationDosageUnit_LitersPerMinute', 'MedicationDosageUnit_Milligrams', 'MedicationDosageUnit_Milligrams', 'MedicationDosageUnit_Milligrams', 'MedicationDosageUnit_Milligrams']
# column name Scene-Response-Patient-Medications-MedicationMedicationDateTimeModValue-MedicationDateTime
# value of the columns ['2020-04-06T11:27:09', '2020-04-06T11:30:09', '2020-04-06T11:34:09', '2020-04-06T11:38:09', '2020-04-06T11:42:02']
# column name Scene-Response-Patient-Medications-MedicationMedicationGivenModValue-MedicationGiven
# value of the columns [488471, 747468, 747468, 747468, 747468]
# column name Scene-Response-Patient-Medications-MedicationResponseToMedicationModValue-ResponseToMedication
# value of the columns ['MedicationResponse_Unchanged', 'MedicationResponse_Unchanged', 'MedicationResponse_Unchanged', 'MedicationResponse_Unchanged', 'MedicationResponse_Improved']
# column name Scene-Response-Patient-Medications-MonitorImport
# value of the columns [False, False, False, False, False]
# column name Scene-Response-Patient-PatientBarriers-PatientBarrierBarrierModValue-Barrier
# value of the columns ['PatientCareBarrier_NoneNoted']
# column name Scene-Response-Patient-PatientEmailAddresses-EmailAddress
# value of the columns ['jrobinson@imagetrend.com']
# column name Scene-Response-Patient-PatientEmailAddresses-EmailAddressType
# value of the columns ['EmailAddressType_Work']
# column name Scene-Response-Patient-PatientPhoneNumbers-PhoneNumber
# value of the columns ['6313600000']
# column name Scene-Response-Patient-PatientPhoneNumbers-PhoneNumberType
# value of the columns ['PhoneNumberType_Mobile']
# column name Scene-Response-Patient-PatientPractitioners-PractitionerFirstName
# value of the columns ['John']
# column name Scene-Response-Patient-PatientPractitioners-PractitionerLastName
# value of the columns ['Hopkins']
# column name Scene-Response-Patient-PatientPractitioners-PractitionerPhone
# value of the columns ['6129524689']
# column name Scene-Response-Patient-PatientProcedures-MonitorImport
# value of the columns [False]
# column name Scene-Response-Patient-PatientProcedures-PatientProcedureComplications-PatientProcedureComplicationProcedureComplicationModValue-ProcedureComplication
# value of the columns [['ProcedureComplicationType_None']]
# column name Scene-Response-Patient-PatientProcedures-PatientProcedureCrewMemberIDModValue-LicensureID
# value of the columns ['1122334455']
# column name Scene-Response-Patient-PatientProcedures-PatientProcedureNumberOfAttemptsModValue-NumberOfAttempt
# value of the columns [1]
# column name Scene-Response-Patient-PatientProcedures-PatientProcedurePatientResponseModValue-PatientResponse
# value of the columns ['ProcedureResponse_Unchanged']
# column name Scene-Response-Patient-PatientProcedures-PatientProcedurePerformerRoleModValue-PerformerRole
# value of the columns ['ProcedurePerformerCertificationLevel_2009Paramedic']
# column name Scene-Response-Patient-PatientProcedures-PatientProcedurePriorToEMSUnitCareModValue-PriorToEMSUnitCare
# value of the columns ['ProcedurePriorToEMSCareStatus_No']
# column name Scene-Response-Patient-PatientProcedures-PatientProcedureProcedureDateTimeModValue-ProcedureDateTime
# value of the columns ['2020-04-06T11:27:09']
# column name Scene-Response-Patient-PatientProcedures-PatientProcedureProcedurePerformedModValue-ProcedurePerformed
# value of the columns [203923]
# column name Scene-Response-Patient-PatientProcedures-PatientProcedureProcedureSuccessfulModValue-ProcedureSuccessful
# value of the columns ['ProcedureSuccessStatus_Yes']
# column name Scene-Response-Patient-PatientProcedures-SizeOfEquipment
# value of the columns ['7.5']
# column name Scene-Response-Patient-PatientRaces-PatientRaceRaceModValue-Race
# value of the columns ['Race_White']
# column name Scene-Response-Patient-PatientSituation-PatientComplaints-PatientComplaintComplaintTypeModValue-ComplaintType
# value of the columns ['ComplaintType_ChiefPrimary']
# column name Scene-Response-Patient-PatientSituation-PatientComplaints-PatientComplaintDurationModValue-Duration
# value of the columns [20]
# column name Scene-Response-Patient-PatientSituation-PatientComplaints-PatientComplaintDurationTimeUnitsModValue-DurationTimeUnit
# value of the columns ['ComplaintDurationTimeUnit_Minutes']
# column name Scene-Response-Patient-ProviderActions-BuiltInPowerToolId
# value of the columns [1]
# column name Scene-Response-Patient-ProviderActions-ProviderActionActivities-ExamID
# value of the columns [[13576]]
# column name Scene-Response-Patient-Signatures-FileType
# value of the columns ['data:image/png;base64', 'data:image/png;base64', 'data:image/png;base64', 'data:image/png;base64']
# column name Scene-Response-Patient-Signatures-FirstName
# value of the columns ['Frank', 'Sara', 'Amy ', 'Jack']
# column name Scene-Response-Patient-Signatures-LastName
# value of the columns ['Reposh2', 'Smith', 'Black', 'Black']
# column name Scene-Response-Patient-Signatures-LicensureID
# value of the columns ['214', None, None, None]
# column name Scene-Response-Patient-Signatures-LockedStatus
# value of the columns [False, False, False, False]
# column name Scene-Response-Patient-Signatures-ParagraphText
# value of the columns [None, None, None, '<br />X - Our Notice of Privacy Practices provides information about how we may use and disclose protected health information about you. You have the right to review our notice before signing this consent. As provided in our notice, the terms of our notice may change. If we change our notice, you may obtain a revised copy. You have the right to request that we restrict how protected health information about you is used or disclosed for treatment, payment or health care operations. We are not required to agree to this restriction, but if we do, we are bound by our agreement. By signing this form, you consent to our use and disclosure of protected health information about you for treatment, payment or health care operations. You have the right to revoke this consent, in writing, except where we have already made disclosures in reliance on your prior consent. \n\n<br />I authorize the release to the Social Security Administration and Centers for Medicare and Medicaid Services, any HMO/PPO, other private or public insurance, or their agents, fiscal intermediaries or carriers or an independent agency performing billing or collection functions on behalf of the ambulance service, any personal, medical or billing information needed for this or a related claim. I understand I will be responsible for any services that are not paid/covered by my insurance. A copy of this authorization shall be valid as the original and shall remain in effect until revoked in writing by the patient/insured. I request payment of medical insurance benefits either to me or to the ambulance service. <br />Advance Beneficiary Notice of Noncoverage (ABN)\nNOTE: If Medicare doesn’t pay for the ambulance services below, you may have to\npay. Medicare does not pay for everything, even some care that you or your health care\nprovider have good reason to think you need. We expect Medicare may not pay for the\nambulance services listed below.\nServices Reason Medicare May Not Pay: Estimated Cost\nAmbulance\nTranport and\nMileage\n• Transportation from a residence to a SNF\n• Ambulance service that is not medically necessary\n• Transports to a doctor’s office or other non-covered\ndetinations\n• Transports for the convenience of a patient, family or\nphysician\n• Mileage beyond the closest appropriate facility\n• Air ambulance service if the patient could have been safely\ntransported by ground ambulance\n$0 - $150,000.00\nAir Amb.\nService\nWHAT YOU NEED TO DO NOW:\n• Read this notice, so you can make an informed decision about your care.\n• Ask us any questions that you may have after you finish reading.\n• Choose an option below about whether to receive the ambulance service listed\nabove.\nNote: If you choose Option 1 or 2, we may help you to use any other\ninsurance that you might have, but Medicare cannot require us to\ndo this.\nOPTIONS: Check only one box. We cannot choose a box for you.\n\U00100001 OPTION 1. I want the ambulance services listed above. You may ask to be paid now, but I also want\nMedicare billed for an official decision on payment, which is sent to me on a Medicare Summary Notice (MSN). I\nunderstand that if Medicare doesn’t pay, I am responsible for payment, but I can appeal to Medicare by following\nthe directions on the MSN. If Medicare does pay, you will refund any payments I made to you, less co-pays or\ndeductibles.\n\U00100001 OPTION 2. I want the ambulance services listed above, but do not bill Medicare. You may ask to be paid\nnow as I am responsible for payment. I cannot appeal if Medicare is not billed.\n\U00100001 OPTION 3. I don’t want the ambulance services listed above. I understand with this choice I am not\nresponsible for payment, and I cannot appeal to see if Medicare would pay.']
# column name Scene-Response-Patient-Signatures-PerformerID
# value of the columns ['2724f3bd-c30d-4d7f-8b55-685eca6b2ae2', None, None, None]
# column name Scene-Response-Patient-Signatures-PersonSigning
# value of the columns ['PersonSigningType_EMSPrimaryCareProvider', 'PersonSigningType_HealthcareProvider', 'PersonSigningType_PatientRepresentative', 'PersonSigningType_Patient']
# column name Scene-Response-Patient-Signatures-SignatureDate
# value of the columns ['2020-04-06T11:44:02', '2020-04-06T11:46:02', '2020-04-06T11:44:02', None]
# column name Scene-Response-Patient-Signatures-SignatureLanguageID
# value of the columns [1, None, 1, 1]
# column name Scene-Response-Patient-Signatures-SignatureReasons-Reason
# value of the columns [['SignatureReason_EMSProvider'], ['SignatureReason_TransferofPatientCare'], ['SignatureReason_HIPAAacknowledgementRelease', 'SignatureReason_PatientMedicalNecessityUnableToSign'], ['SignatureReason_HIPAAacknowledgementRelease', 'SignatureReason_PermissiontoTreat', 'SignatureReason_PermissionToTransport', 'SignatureReason_ReleaseforBilling']]
# column name Scene-Response-Patient-Signatures-Status
# value of the columns [None, None, None, 'SignatureStatus_NotSignedUnconscious']
# column name Scene-Response-Patient-Signatures-TypeOfPatientRepresentative
# value of the columns [None, None, 'PatientRepresentativeType_PowerofAttorney', None]
# column name Scene-Response-Patient-Vitals-ECGCardiacRhythms-ECGCardiacRhythmCardiacRhythmModValue-CardiacRhythm
# value of the columns [['CardiacRhythmElectrocardiographyType_Asystole'], ['CardiacRhythmElectrocardiographyType_SinusTachycardia']]
# column name Scene-Response-Patient-Vitals-MeanArterialPressure
# value of the columns [None, 70]
# column name Scene-Response-Patient-Vitals-MonitorImport
# value of the columns [False, False]
# column name Scene-Response-Patient-Vitals-VitalsBPMethodModValue-BPMethod
# value of the columns [None, 'BloodPressureMeasurementMethod_CuffAutomated']
# column name Scene-Response-Patient-Vitals-VitalsDBPModValue-DBP
# value of the columns [None, 60]
# column name Scene-Response-Patient-Vitals-VitalsGCSEyeModValue-GCSEye
# value of the columns ['GCSEyeObservation_NoeyemovementwhenassessedAllAgeGroups', 'GCSEyeObservation_NoeyemovementwhenassessedAllAgeGroups']
# column name Scene-Response-Patient-Vitals-VitalsGCSMotorModValue-GCSMotor
# value of the columns ['GCSMotorObservation_NoMotorResponseAllAgeGroups', 'GCSMotorObservation_NoMotorResponseAllAgeGroups']
# column name Scene-Response-Patient-Vitals-VitalsGCSTotalModValue-GCSTotal
# value of the columns [3, 3]
# column name Scene-Response-Patient-Vitals-VitalsGCSVerbalModValue-GCSVerbal
# value of the columns ['GCSVerbalObservation_NoverbalvocalresponseAllAgeGroups', 'GCSVerbalObservation_NoverbalvocalresponseAllAgeGroups']
# column name Scene-Response-Patient-Vitals-VitalsLevelOfResponseModValue-LevelOfResponse
# value of the columns ['ResponsivenessLevel_Unresponsive', 'ResponsivenessLevel_Unresponsive']
# column name Scene-Response-Patient-Vitals-VitalsObtainedPriorToEMSCareModValue-NotValue
# value of the columns ['ObtainedPriorToEMSCareStatus_NotValue_NotRecorded', 'ObtainedPriorToEMSCareStatus_NotValue_NotRecorded']
# column name Scene-Response-Patient-Vitals-VitalsPulseOximetryModValue-PulseOximetry
# value of the columns [None, 95]
# column name Scene-Response-Patient-Vitals-VitalsPulseRateModValue-PulseRate
# value of the columns [0, 120]
# column name Scene-Response-Patient-Vitals-VitalsRTSModValue-RT
# value of the columns [None, 4]
# column name Scene-Response-Patient-Vitals-VitalsRespiratoryRateModValue-RespiratoryRate
# value of the columns [0, 0]
# column name Scene-Response-Patient-Vitals-VitalsSBPModValue-SBP
# value of the columns [None, 90]
# column name Scene-Response-Patient-Vitals-VitalsVitalsDateTimeModValue-VitalsDateTime
# value of the columns ['2020-04-06T11:27:09', '2020-04-06T11:43:02']
# column name Scene-Response-ResponseModes-ResponseModeResponseModeModValue-ResponseMode
# value of the columns ['ResponseModeDescriptor_LightsAndSirens']

# %%
from pyspark.sql import functions as F

flattened_df = flattened_df.withColumn(
    'Scene-Response-Patient-Vitals-VitalsGCSTotalModValue-GCSTotal',
    F.when(
        (F.array_contains(F.col('Scene-Response-Patient-Vitals-VitalsGCSTotalModValue-GCSTotal'), 3)) | 
        (F.array_contains(F.col('Scene-Response-Patient-Vitals-VitalsGCSTotalModValue-GCSTotal'), 8)),
        'severe'
    )
    .when(
        (F.array_contains(F.col('Scene-Response-Patient-Vitals-VitalsGCSTotalModValue-GCSTotal'), 9)) | 
        (F.array_contains(F.col('Scene-Response-Patient-Vitals-VitalsGCSTotalModValue-GCSTotal'), 12)),
        'moderate'
    )
    .when(
        (F.array_contains(F.col('Scene-Response-Patient-Vitals-VitalsGCSTotalModValue-GCSTotal'), 13)) | 
        (F.array_contains(F.col('Scene-Response-Patient-Vitals-VitalsGCSTotalModValue-GCSTotal'), 14)),
        'mild'
    )
    .otherwise('normal')
)

# %%
flattened_df.write.parquet("Flattened_json.parquet")

# %%
# mv Flattened_json.parquet /Workspace/Users/chaitu.wynbit@outlook.com/data
